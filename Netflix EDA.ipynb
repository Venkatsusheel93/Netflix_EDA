# %%
# importing all librabries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
# reading the csv file with different encodings
try: 
    df = pd.read_csv("C:/Users/sanne/OneDrive/Desktop/EDA/netflix EDA.csv", encoding = 'utf-8')
    
except UnicodeDecodeError:
    
    df= pd.read_csv("C:/Users/sanne/OneDrive/Desktop/EDA/netflix EDA.csv", encoding = 'latin1')
    
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type               title         director  \
# 8804   s8805    Movie          Zombieland  Ruben Fleischer
# 8805   s8806    Movie                Zoom     Peter Hewitt
# 8806   s8807    Movie              Zubaan      Mozez Singh
# 8807   s8808  TV Show  Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie              Serena     Susanne Bier
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 8807         Shin Hyun-been, Jeon Yeo-bin, Goo Kyo-hwan    South Korea
# 8808  Bradley Cooper, Jennifer Lawrence, Toby Jones,...  United States
#
#             date_added  release_year rating  duration  \
# 8804  November 1, 2019          2009      R    88 min
# 8805  January 11, 2020          2006     PG    88 min
# ...

# %%
df.shape # 8809 rows, 12 columns
# Out:
# (8809, 12)

# %%
df.size  #(8809*12 = 1,05,708)
# Out:
# 105708

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8809 entries, 0 to 8808
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8809 non-null   object
#  1   type          8809 non-null   object
#  2   title         8809 non-null   object
#  3   director      6175 non-null   object
#  4   cast          7984 non-null   object
#  5   country       7978 non-null   object
#  6   date_added    8799 non-null   object
#  7   release_year  8809 non-null   int64
#  8   rating        8805 non-null   object
#  9   duration      8806 non-null   object
#  10  listed_in     8809 non-null   object
#  11  description   8809 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 826.0+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8809.000000
# mean    2014.181292
# std        8.818932
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2024.000000

# %%
df[df.duplicated]  # no duplicates in the given dataaset
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# if there is any duplicates record, we can use the above syntax
df.drop_duplicates(inplace = True)   # it will drop all the duplicate record in the dataset

# %%
null_df = df.isnull()
null_df  # null_values
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
# 8807    False  False  False     False  False    False       False
# 8808    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
# each column has how many values
null_df.sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(null_df)
# Out:
# <Axes: >

# %%
df.isnull().sum().sum()
# Out:
# 4307

# %%
df2 = df.fillna(value = 0)
df2
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water                0
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans                0
# 4         s5  TV Show           Kota Factory                0
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# let's search for a famouse netflix show title ie., 'House of cards' to fetch all details of this TV show
df['title']
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# 8807       Parasyte: The Grey
# 8808                   Serena
# Name: title, Length: 8809, dtype: object

# %%
df['title'].isin(['House of Cards']) # to show all records of a particular item in any column
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8804    False
# 8805    False
# 8806    False
# 8807    False
# 8808    False
# Name: title, Length: 8809, dtype: bool

# %%
df[df['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
# In which year highest movies and tv shows were released? show them in bar graph
year_ = df['release_year'].value_counts()
year_.plot(kind = 'bar')
# Out:
# <Axes: xlabel='release_year'>

# %%
# as you can see the above graph is not readable so, we categorize the data like 1975 to 2000 as 1975-2000 something like that.
df['release_year'].min()
# Out:
# 1925

# %%
df['release_year'].max() # maximum_year or recent_year
# Out:
# 2024

# %%
labels = ['1925-34','1935-44','1945-54','1955-64','1965-74','1975-84','1985-94','1995-04','2005-14','2015-24']
bins = [1924,1934,1944,1954,1964,1974,1984,1994,2004,2014,2024]
df['year'] = pd.cut(df['release_year'],bins = bins,labels = labels,right = True)
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['year'].value_counts().plot(kind = 'bar')
plt.xlabel('Year_range')
plt.ylabel('value_counts')
plt.title('Number of Movies by each year_category')
plt.xticks(rotation = 45)
plt.show()

# %%
df.groupby('type').type.count()
# Out:
# type
# Movie      6132
# TV Show    2677
# Name: type, dtype: int64

# %%
sns.countplot(x = df['type'])
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'year'],
#       dtype='object')

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# show all the movies that were released in the year 2020
x = df[(df['type'] == 'Movie') & (df['release_year'] == 2020)] 
x
# Out:
#      show_id   type                                              title  \
# 0         s1  Movie                               Dick Johnson Is Dead
# 16       s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 78       s79  Movie                                     Tughlaq Durbar
# 84       s85  Movie                               Omo Ghetto: the Saga
# 103     s104  Movie                                     Shadow Parties
# ...      ...    ...                                                ...
# 3046   s3047  Movie                      All the Freckles in the World
# 3060   s3061  Movie                                      Ghost Stories
# 5972   s5973  Movie                                   #cats_the_mewvie
# 7594   s7595  Movie                 Norm of the North: Family Vacation
# 8099   s8100  Movie                                        Straight Up
#
#                                                director  \
# 0                                       Kirsten Johnson
# ...

# %%
# how many rows
count_len = len(x)
print(f"{count_len} rows")
# Out:
# 517 rows

# %%
# show only the titles of all TV shows that were released in India only
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df[(df['type'] =='TV Show') & (df['country'] == 'India')]['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %%
# show top 10 directories, who gave the highest number of TV shows & Movies to netflix
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka              19
# Ra̼l Campos, Jan Suter    18
# Marcus Raboy               16
# Suhas Kadav                16
# Jay Karas                  14
# Cathy Garcia-Molina        13
# Youssef Chahine            12
# Martin Scorsese            12
# Jay Chapman                12
# Steven Spielberg           11
# Name: count, dtype: int64

# %%
# show all the records, where type is Movie and type is comedies or country is uk
df[(df['type'] == 'Movie') & (df['listed_in'] == 'Comedies') | (df['country'] == 'United Kingdom')]
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              director                                               cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
# In how many movies/shows, Tom cruise was cast?
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df[df['cast'] == 'Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, year]
# Index: []

# %%
df[df['cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[497], line 1
# ----> 1 df[df['cast'].str.contains('Tom Cruise')]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3751, in DataFrame.__getitem__(self, key)
#    3748     return self.where(key)
#    3750 # Do we have a (boolean) 1d indexer?
# -> 3751 if com.is_bool_indexer(key):
#    3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\common.py:134, in is_bool_indexer(key)
#     130     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     131     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
# ...

# %%
# to remove the null_values from the cast_column, 
# creating a new data_frame ie., (df2)
df2 = df.dropna()
df2
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
# 8807   s8808  TV Show             Parasyte: The Grey         Yeon Sang-ho
# 8808   s8809    Movie                         Serena         Susanne Bier
#
#                                                    cast  \
# ...

# %%
df2[df2['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description     year
# 341   Through chance, history and divine interventio...  1995-04
# 1254  Motivated by money, a selfish workaholic seeki...  1985-94

# %%
# What are the different ratings defined by Netflix
df['rating'].nunique() # these tells about the number of differnt ratings in data as.,
# Out:
# 18

# %%
df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR', 'A'], dtype=object)

# %%
# how many Movies got the TV-14 rating in canada
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     year
# 0  As her father nears the end of his life, filmm...  2015-24
# 1  After crossing paths at a party, a Cape Town t...  2015-24

# %%
df[(df['type'] =='Movie') & (df['rating'] =='TV-14') & (df['country'] =='Canada')]
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 1279   s1280  Movie   Made You Look: A True Story About Fake Art
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5972   s5973  Movie                             #cats_the_mewvie
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8178   s8179  Movie                  The Accountant of Auschwitz
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# ...

# %%
# how many Tv shows got the R rating after year 2018
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     year
# 0  As her father nears the end of his life, filmm...  2015-24
# 1  After crossing paths at a party, a Cape Town t...  2015-24

# %%
df[(df['type'] =='TV Show') & (df['rating'] == 'R') & (df['release_year'] > 2018)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, year]
# Index: []

# %%
# what is the maimum duration of Movie/Tv show on netflix
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     year Minutes    Units
# 0  As her father nears the end of his life, filmm...  2015-24      90      min
# 1  After crossing paths at a party, a Cape Town t...  2015-24       2  Seasons

# %%
df['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
df['duration'].dtypes
# Out:
# dtype('O')

# %%
# str.split()
df[['Minutes','Units']] = df['duration'].str.split(' ',expand = True)

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     year Minutes    Units
# 0  As her father nears the end of his life, filmm...  2015-24      90      min
# 1  After crossing paths at a party, a Cape Town t...  2015-24       2  Seasons

# %%
df['Minutes'].value_counts().max()
# Out:
# 1794

# %%
df['Minutes'].value_counts().min()
# Out:
# 1

# %%
df['Minutes'].value_counts().mean()
# Out:
# 41.93333333333333

# %%
# which individual country has the Highest Number of TV shows?
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     year Minutes    Units
# 0  As her father nears the end of his life, filmm...  2015-24      90      min
# 1  After crossing paths at a party, a Cape Town t...  2015-24       2  Seasons

# %%
df_tvshow = df[df['type'] == 'TV Show']

# %%
df_tvshow.head(2)
# Out:
#   show_id     type          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description     year Minutes    Units
# 1  After crossing paths at a party, a Cape Town t...  2015-24       2  Seasons
# 2  To protect his family from a powerful drug lor...  2015-24       1   Season

# %%
df_tvshow['country'].value_counts().head(1)
# Out:
# country
# United States    760
# Name: count, dtype: int64

# %%
# how can we sort the dataset by year
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     year Minutes    Units
# 0  As her father nears the end of his life, filmm...  2015-24      90      min
# 1  After crossing paths at a party, a Cape Town t...  2015-24       2  Seasons

# %%
df.sort_values(by = 'release_year').head(2)
# Out:
#      show_id     type                              title     director cast  \
# 4250   s4251  TV Show  Pioneers: First Women Filmmakers*          NaN  NaN
# 7790   s7791    Movie                     Prelude to War  Frank Capra  NaN
#
#             country         date_added  release_year rating  duration  \
# 4250            NaN  December 30, 2018          1925  TV-14  1 Season
# 7790  United States     March 31, 2017          1942  TV-14    52 min
#
#                           listed_in  \
# 4250                       TV Shows
# 7790  Classic Movies, Documentaries
#
#                                             description     year Minutes  \
# 4250  This collection restores films from women who ...  1925-34       1
# 7790  Frank Capra's documentary chronicles the rise ...  1935-44      52
#
#        Units
# 4250  Season
# 7790     min

# %%
df.sort_values(by = 'release_year', ascending = False).head(2)
# Out:
#      show_id     type                   title        director  \
# 8807   s8808  TV Show      Parasyte: The Grey    Yeon Sang-ho
# 693     s694    Movie  Ali & Ratu Ratu Queens  Lucky Kuswandi
#
#                                                    cast      country  \
# 8807         Shin Hyun-been, Jeon Yeo-bin, Goo Kyo-hwan  South Korea
# 693   Iqbaal Ramadhan, Nirina Zubir, Asri Welas, Tik...          NaN
#
#          date_added  release_year rating  duration  \
# 8807  April 5, 2024          2024  TV-MA  1 Season
# 693   June 17, 2021          2021  TV-14   101 min
#
#                                    listed_in  \
# 8807                  Sci-fi, Horror, Action
# 693   Comedies, Dramas, International Movies
#
#                                             description     year Minutes  \
# 8807  A new breed of parasitic aliens arrive on Eart...  2015-24       1
# 693   After his father's passing, a teenager sets ou...  2015-24     101
#
#        Units
# 8807  Season
# 693      min

# %%
# find all the instances where :
# category is 'Movie' and Type is 'Dramas' or category is 'TV Show' and Type is 'Kids TV'
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     year Minutes    Units
# 0  As her father nears the end of his life, filmm...  2015-24      90      min
# 1  After crossing paths at a party, a Cape Town t...  2015-24       2  Seasons

# %%
df[(df['type'] =='Movie') & (df['listed_in'] == 'Dramas')].head(2)
# Out:
#     show_id   type               title          director  \
# 112    s113  Movie               Worth    Sara Colangelo
# 129    s130  Movie  An Unfinished Life  Lasse Hallstr̦m
#
#                                                   cast  \
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129  Robert Redford, Jennifer Lopez, Morgan Freeman...
#
#                     country         date_added  release_year rating duration  \
# 112                     NaN  September 3, 2021          2021  PG-13  119 min
# 129  Germany, United States  September 1, 2021          2005  PG-13  108 min
#
#     listed_in                                        description     year  \
# 112    Dramas  In the wake of the Sept. 11 attacks, a lawyer ...  2015-24
# 129    Dramas  A grieving widow and her daughter move in with...  2005-14
#
#     Minutes Units
# 112     119   min
# 129     108   min

# %%
df[(df['type'] == 'TV Show') & (df['listed_in'] == 'Kids TV')].head(2)
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, year, Minutes, Units]
# Index: []

# %%
df[(df['type'] =='Movie') & (df['listed_in'] == 'Dramas') | (df['type'] == 'TV Show') & (df['listed_in'] == 'Kids TV')]
# Out:
#      show_id   type                title             director  \
# 112     s113  Movie                Worth       Sara Colangelo
# 129     s130  Movie   An Unfinished Life     Lasse Hallstr̦m
# 142     s143  Movie      Freedom Writers  Richard LaGravenese
# 162     s163  Movie             Marshall      Reginald Hudlin
# 329     s330  Movie  Catch Me If You Can     Steven Spielberg
# ...      ...    ...                  ...                  ...
# 8674   s8675  Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676  Movie               Victor    Brandon Dickerson
# 8685   s8686  Movie                  VS.             Ed Lilly
# 8691   s8692  Movie            Wakefield        Robin Swicord
# 8696   s8697  Movie            War Horse     Steven Spielberg
#
#                                                    cast  \
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# ...

# %%
df.dtypes
# Out:
# show_id           object
# type              object
# title             object
# director          object
# cast              object
# country           object
# date_added        object
# release_year       int64
# rating            object
# duration          object
# listed_in         object
# description       object
# year            category
# Minutes           object
# Units             object
# dtype: object

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
# 8807   s8808  TV Show     Parasyte: The Grey     Yeon Sang-ho
# 8808   s8809    Movie                 Serena     Susanne Bier
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# correlation for the numerical columns
correlation_matrix = df[numerical_columns].corr()
plt.figure(figsize = (10,8))
sns.heatmap(correlation_matrix, annot = True, cmap = 'coolwarm', fmt = '.2f', linewidths =0.5 )
plt.title('Correlation Heatmap')
plt.show()
